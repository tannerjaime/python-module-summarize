# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
return_type='axes'

nba_pd = pd.read_csv('/Users/Andy/Documents/Python_Project/python-module-summarize/nba_stats.csv')

nba_np = genfromtxt('/Users/Andy/Documents/Python_Project/python-module-summarize/nba_stats.csv', delimiter=',')

# %%
type(nba_pd)
# Out:
# pandas.core.frame.DataFrame

# %%
type(nba_np)
# Out:
# numpy.ndarray

# %%
def check_input_data(data):
	""" check that input data is a pandas dataframe or series or a numpy ndarray """
	""" convert input to pandas dataframe (if not one already) """
	""" return error if input is not any of these data structures """
	structure = type(data)
	return structure

# %%
check_input_data(nba_pd)
# Out:
# pandas.core.frame.DataFrame

# %%
check_input_data(nba_np)
# Out:
# numpy.ndarray

# %%
def summarize(data):
	""" method to summarize and visualize self.data """
	summary = data.describe(include = 'all')
	bxPlt = data.plot.box(return_type='axes', figsize=(20,20))
	histogram = data.hist(figsize=(20,20))
	return summary
	print(histogram)
	print(bxPlt)

# %%
summarize(nba_pd)
# Out:
#                  Player         Age   Tm          MP         RBS         AST  \
# count               492  492.000000  492  492.000000  492.000000  492.000000
# unique              492         NaN   31         NaN         NaN         NaN
# top     Hollis Thompson         NaN  TOT         NaN         NaN         NaN
# freq                  1         NaN   76         NaN         NaN         NaN
# mean                NaN   26.536585  NaN   20.175407    3.543293    1.819512
# std                 NaN    4.193473  NaN    9.094459    2.423026    1.735453
# min                 NaN   19.000000  NaN    0.700000    0.000000    0.000000
# 25%                 NaN   23.000000  NaN   13.075000    1.800000    0.700000
# 50%                 NaN   26.000000  NaN   19.750000    3.000000    1.200000
# 75%                 NaN   29.000000  NaN   27.800000    4.800000    2.400000
# max                 NaN   38.000000  NaN   38.700000   15.000000   10.200000
#
#                STL         BLK         TOV         PTS      FG_per     FT_perc
# count   492.000000  492.000000  492.000000  492.000000  490.000000  475.000000
# unique         NaN         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN         NaN
# mean      0.648577    0.387195    1.152236    8.122561    0.433033    0.726752
# std       0.428822    0.446141    0.765907    5.499598    0.097686    0.146236
# min       0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       0.300000    0.100000    0.600000    4.000000    0.396000    0.658500
# 50%       0.600000    0.200000    1.000000    6.900000    0.429500    0.752000
# 75%       0.900000    0.500000    1.500000   11.625000    0.476000    0.822000
# max       2.300000    2.900000    4.400000   28.100000    1.000000    1.000000

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-5e80552ddf6e> in <module>()
# ----> 1 summarize(nba_np)
#
# <ipython-input-63-95d0ed514ba0> in summarize(data)
#       3 def summarize(data):
#       4         """ method to summarize and visualize self.data """
# ----> 5         summary = data.describe(include = 'all')
#       6         bxPlt = data.boxplot(figsize=(30,30))
#       7         histogram = data.hist(figsize=(20,20))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'
